# %%
#pip? : 파이썬의 앱스토어 같은 도구
# 다른 사람이 만들어 둔 파이썬 라이브러리를 설치/삭제/목록 확인을 해줌

# pip install 모듈이름
# pip uninstal numpy
# pip list

# %%
#운영체제 모듈 불러오기
import os
print(os.getcwd())
# Out:
# c:\파이썬 수업\work\python_exam

# %%
#디렉토리를 이동할 수 있게 해주는 함수
#한국어 인식이 안되기 떄문에 웬만하면 영어로

# %%
# 입력한 경로의 파일과 폴더 목록을 리스트로 변환하는 함수
os.listdir("C:\\work")

for i in os.listdir("C:\\work"):
    print(i)

# %%
# 특정 폴더가 존재하는지 확인하는함수
print(os.path.exsists("C:\\work/py_test"))
print(os.path.exsists("C:\\work/python_exam"))

# %%
print(os.getcwd())
#폴더를 만들어주는 함수
os.mkdir("py_test")

# 새로운 폴더와 그 하위 폴더까지 만드는 함수
os.makedirs("C:/py_test2/py_test222")
# Out:
# c:\파이썬 수업\work\python_exam

# %%
#폴더를 삭제하는함수
os.rmdir("C:/py_test2")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 #폴더를 삭제하는함수
# ----> 2 os.rmdir("C:/py_test2")
#
# OSError: [WinError 145] 디렉터리가 비어 있지 않습니다: 'C:/py_test2'
